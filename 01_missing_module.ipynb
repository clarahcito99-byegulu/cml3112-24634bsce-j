# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %% [markdown]
# **Predicted error:** ModuleNotFoundError, because `course_package_not_installed` is not a real installed package. Original broken line was: `import course_package_not_installed`
#
# **Cause:** the import points to a package name that does not exist in this environment, so Python cannot find it and raises ModuleNotFoundError.
#
# **Repair:** removed the broken import below, since it was never actually needed for this notebook to run.

# %%
# Repaired: broken import removed.
print("No broken import remaining.")
# Out:
# No broken import remaining.
