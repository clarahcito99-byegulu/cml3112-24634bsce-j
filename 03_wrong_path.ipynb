# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
with open("site_inspection_log.csv") as f:
    print(f.readline())
# Out:
# reading_id,crack_width_mm

# %% [markdown]
# **Predicted error:** FileNotFoundError, because the code looks for the CSV inside a folder called `missing_folder`, which does not exist.
#
# **Cause:** the path `"missing_folder/site_inspection_log.csv"` is wrong; the CSV actually sits in the same folder as the notebook, not inside `missing_folder`.
#
# **Repair:** removed `missing_folder/` from the path so it just opens `"site_inspection_log.csv"` directly.
