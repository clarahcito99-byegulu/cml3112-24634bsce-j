# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
import sys
assert sys.version_info.major == 3, "Notebook expects Python 3, which the course uses"

# %% [markdown]
# **Predicted error:** AssertionError, because the original assert checked for Python 2, but this course runs on Python 3.
#
# **Cause:** the assert condition was `sys.version_info.major == 2`, which is always false on our Python 3 kernel, so the assertion always fails.
#
# **Repair:** changed the condition to check for `== 3` instead of `== 2`, matching the actual runtime.
